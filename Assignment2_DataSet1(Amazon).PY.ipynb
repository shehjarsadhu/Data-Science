# %%
import pandas as pd

# %%
amazon = pd.read_csv("amzn-anon-access-samples-history-2.0.csv")

# %%
amazon
# Out:
#                ACTION  TARGET_NAME  LOGIN         REQUEST_DATE  \
# 0       remove_access        11044  45813  2005-03-25 10:53:40
# 1          add_access        11044  65766  2005-03-25 10:55:46
# 2          add_access         9521  72531  2005-04-04 13:51:33
# 3          add_access         9521  72531  2005-04-04 13:52:01
# 4          add_access         9521  72531  2005-04-04 13:52:11
# 5          add_access        10339  65338  2005-04-05 10:37:48
# 6          add_access         9521  72531  2005-04-05 16:20:29
# 7       remove_access          154  74430  2005-04-05 19:59:15
# 8       remove_access         9669  59618  2005-04-06 08:40:03
# 9          add_access         7315  77213  2005-03-25 14:15:20
# 10         add_access         7315  77213  2005-03-25 14:15:31
# 11         add_access         7315  77213  2005-03-25 14:15:39
# 12         add_access         9521  48927  2005-03-25 14:38:51
# 13         add_access         9521  70554  2005-03-25 14:39:53
# ...

# %% [markdown]
# Question 1: How many columns are there? 5

# %% [markdown]
# Question 2: How many rows are there? 716063

# %%
amazon.shape
# Out:
# (716063, 5)

# %% [markdown]
# Question 3:
#     The above data is numerical and column 2 which is ACTION is caterogical

# %% [markdown]
# Question 4: Are there columns that provide no information? Just constant values for all observations.

# %% [markdown]
# Question 6 : For each numerical column compute the mean (average), max, and min values.

# %%
amazon.describe()
# Out:
#          TARGET_NAME          LOGIN
# count  716063.000000  716063.000000
# mean     7783.500502   57160.214153
# std      2836.962280   12372.981037
# min        11.000000       0.000000
# 25%      6167.000000   46779.000000
# 50%      8557.000000   57509.000000
# 75%      9870.000000   67667.000000
# max     35217.000000   78181.000000

# %% [markdown]
# Question 5: For each categorical columns compute the mode.

# %%
amazon.head()
# Out:
#           ACTION  TARGET_NAME  LOGIN         REQUEST_DATE   AUTHORIZATION_DATE
# 0  remove_access        11044  45813  2005-03-25 10:53:40  2005-03-25 10:53:41
# 1     add_access        11044  65766  2005-03-25 10:55:46  2005-03-25 10:55:47
# 2     add_access         9521  72531  2005-04-04 13:51:33  2005-04-06 10:21:48
# 3     add_access         9521  72531  2005-04-04 13:52:01  2005-04-06 10:21:48
# 4     add_access         9521  72531  2005-04-04 13:52:11  2005-04-06 10:21:49

# %%
amazon.describe()
# Out:
#          TARGET_NAME          LOGIN
# count  716063.000000  716063.000000
# mean     7783.500502   57160.214153
# std      2836.962280   12372.981037
# min        11.000000       0.000000
# 25%      6167.000000   46779.000000
# 50%      8557.000000   57509.000000
# 75%      9870.000000   67667.000000
# max     35217.000000   78181.000000

# %% [markdown]
# Question 7: Plot histograms for numerical columns.

# %%
# %matplotlib inline

# %%
amazon.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115b388d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11644c978>]], dtype=object)

# %%
amazon.plot(kind='bar')

# %% [markdown]
#  This is an anonymized sample of access provisioned within the company. It measures the access data sample at a specfic authorises date and request date .

# %% [markdown]
# Question 8: Plot bar plots for categorical columns.
