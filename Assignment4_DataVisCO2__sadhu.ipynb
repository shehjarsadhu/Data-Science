# %%
# %matplotlib inline
import pandas as pd

# %%
co2_df = pd.read_csv("leaftemp.all.csv")
co2_df.head()
# Out:
#    Unnamed: 0 glasshouse CO2level  day        light         CO2  tempDiff  \
# 0           1          A     high    0  1143.060000  127.112222  1.835037
# 1           2          B      low    0  1143.060000   39.854833  1.542604
# 2           3          C   medium    0  1143.060000   70.938111  1.962119
# 3           4          A     high    1   465.810556  128.404444  0.928792
# 4           5          B      low    1   465.810556   40.996556  0.680829
#
#    BtempDiff    airTemp  vapPress
# 0   1.496457  26.047167  2.563877
# 1   1.355216  24.102750  1.878973
# 2   1.942780  26.711556  2.375940
# 3   0.849522  25.135167  2.546759
# 4   0.599220  24.899306  2.198131

# %%
co2_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# The Histogram:For displaying basic distribution information of numeric columns. In this case CO2 levels.

# %%
co2_df.loc[:,'CO2'].plot.hist(bins=5)

# %% [markdown]
# Density Plot:- An alternative to histograms are density plots (kernel density estimators - kde) which display the same information in a continuous format

# %%
co2_df.loc[:,'CO2'].plot.kde()

# %% [markdown]
# The Bar Chart:-Here we have to do some preprocessing before we can plot the levels of the column - we have to actually count the number of times particular levels occur in a categorical column. The function value_counts can be applied the categorical columns which creates a table of the number of times each label occurred in a column.

# %%
co2_df.loc[:,'CO2level'].value_counts()
# Out:
# medium    21
# high      21
# low       20
# Name: CO2level, dtype: int64

# %% [markdown]
# Building the bar graph!

# %%
co2_df.loc[:,'CO2level'].value_counts().plot.bar()

# %% [markdown]
# The Pie Chart:- The same information as the bar chart can be displayed in a visually appealing pie chart. The only caveat here is that we want to get rid of the column/series name because the package displays it in kind of a strange fashion.

# %%
plot_series = co2_df.loc[:,'CO2level'].rename('') # get rid of the 'Species' label

# %%
plot_series.value_counts().plot.pie() # plot the value counts of the labels

# %% [markdown]
# Scatter Plots:- Scatter plots allow us to examine the relationship between columns in a dataframe

# %%
co2_df.plot.scatter(x='airTemp', y='CO2')

# %%
null = pd.plotting.scatter_matrix(co2_df, figsize=[10,10])

# %%
import seaborn as sns
sns.set()

# %%
co2_df = pd.read_csv("leaftemp.all.csv")
co2_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# Histograms:-In the Seaborn world this is done with distplot

# %%
sns.distplot(co2_df.loc[:,'CO2'], hist=True, kde=True, bins=5)

# %%
sns.distplot(co2_df.loc[:,'CO2'], hist=True, kde=False, bins=None)

# %%
sns.countplot(co2_df.loc[:,'CO2level']) #no pre processing required.

# %%
sns.pairplot(co2_df, hue='CO2level', size=2)

# %%
sns.pairplot(co2_df, hue='CO2level', size=3, vars=["CO2", "airTemp"]) #looking at individual pairs

# %% [markdown]
# Seaborn has another plot called the jointplot that allows you to compare two variables. Here is one that draws a scatterplot with marginal histograms.

# %%
sns.jointplot(x="CO2", y="airTemp", data=co2_df, size=6) #Joint Plot

# %% [markdown]
# Same thing as a density plot.

# %%
sns.jointplot(x="CO2", y="airTemp", data=co2_df, size=6, kind="kde", color="g")

# %% [markdown]
# Use the visualization tools presented in this slide set to look at the data set. Are your independent variables uni- or multimodal?
# Q) Can you identify clusters when performing scatter plots?
# A)  Yes, the clusters are mostely between 26-27 air temp.
# Q) Are those clusters related to your decision tree model?
# Q) What about the different levels of your dependent variable - are they equally represented?
# A) Dependent variable is :- CO2level it contains 3 types high,medium,low.

# %% [markdown]
# Find the simplest decision tree model whose accuracy is only 10% worse than the best model you can build.
# How does the best decision tree model and your new model compare in terms of interpretability?
# Do they agree on the major trends?
